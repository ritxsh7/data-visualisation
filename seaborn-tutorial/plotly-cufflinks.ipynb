# %%
import pandas as pd
import numpy as np

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
import cufflinks as cf

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#DATA
df1 = pd.DataFrame(np.random.randn(100,4), columns=['A', 'B', 'C', 'D'])
df1
# Out:
#            A         B         C         D
# 0   0.484326 -1.007298 -0.029728  0.256787
# 1  -0.835408 -0.495044  1.932486 -1.513327
# 2   1.466206 -1.105127  1.407303 -1.359736
# 3   0.753496 -0.504877  0.437464 -0.664035
# 4   0.103791 -0.617900  1.072148 -0.058680
# ..       ...       ...       ...       ...
# 95  0.702628 -1.674609 -0.982917 -0.224276
# 96 -0.207681  0.596652 -0.163493 -1.304814
# 97 -1.370142  0.755208 -0.535499  0.531561
# 98  1.026795 -2.022606  0.611449  1.690844
# 99 -0.325271  0.229094 -0.845540  1.737018
#
# [100 rows x 4 columns]

# %%
#Plotly and cufflinks enhances the existing plots availble with some addtional features
df1.iplot()
# Out:
# <div>                            <div id="8eb9251a-f4df-4b8a-8179-e5c2a64ff86e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.iplot(x='C', y='B', kind='scatter', mode='markers')
# Out:
# <div>                            <div id="2915a9b7-c040-48c0-866b-6211b43823d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2 = pd.DataFrame({'Category' : ['A', 'B', 'C', 'D'], 'Values' : [30, 20, 80, 10]})
df2
# Out:
#   Category  Values
# 0        A      30
# 1        B      20
# 2        C      80
# 3        D      10

# %%
df2.iplot(kind='bar', x='Category', y='Values')
# Out:
# <div>                            <div id="e461b0a0-25ab-4c96-90e2-d12da088e0f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.sum().iplot(kind='bar')
# Out:
# <div>                            <div id="60e62cbf-1ee3-492b-b12b-d2ded9d6c0f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.iplot(kind='box')
# Out:
# <div>                            <div id="ee640131-b281-4f2f-9326-29044de95df0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
